# %% [markdown]
# <font color='blue' size=5><b>Комментарий ревьюера</b></font>
#
# <font color='blue'>Привет, Станислав! Меня зовут Павел Григорьев, и я буду проверять этот проект.<br>Моя основная цель - не указать на совершённые тобой ошибки, а поделиться своим опытом и помочь тебе совершенствоваться как профессионалу.<br>Спасибо за проделанную работу! Предлагаю общаться на «ты».</font>
# <details>
# 	<summary><u>Инструкция по организационным мометнам (кликабельно)</u></summary>
# <font color='blue'>Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</font>
#
#
# ---
#
#
# <font color='blue'>синий текст - просто текст комментария</font>
#
# <font color='green'>✔️ и зеленый текст - все отлично</font>
#
# <font color='orange'>⚠️ и оранжевый текст - сделано все правильно, однако есть рекомендации, на что стоит обратить внимание</font>
#
# <font color='red'>❌ и красный текст - есть недочеты</font>
#
#
# </details>
#     </br>
# <font color='blue'>Пожалуйста, не удаляй мои комментарии в случае возврата работы, так будет проще разобраться, какие были недочеты, а также сразу увидеть исправленное. </font>
#
# Ответы на мои комментарии лучше тоже помечать.
# Например: <font color='purple'><b>Комментарий студента</b></font>
#
# <font color='blue'><b>Давай смотреть, что получилось!</b></font>

# %% [markdown]
# <font color='blue' size=3><b>Комментарий ревьюера 2</b></font>
#
# <font color='blue'>Привет еще раз. Спасибо, за исправления. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.</font>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Импорт--и-установка-библиотек" data-toc-modified-id="Импорт--и-установка-библиотек-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Импорт  и установка библиотек</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы." data-toc-modified-id="Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы.-1.0.1"><span class="toc-item-num">1.0.1&nbsp;&nbsp;</span>Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.</a></span></li><li><span><a href="#Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?" data-toc-modified-id="Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?-1.0.2"><span class="toc-item-num">1.0.2&nbsp;&nbsp;</span>Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?</a></span></li><li><span><a href="#Проведите-предобработку-данных." data-toc-modified-id="Проведите-предобработку-данных.-1.0.3"><span class="toc-item-num">1.0.3&nbsp;&nbsp;</span>Проведите предобработку данных.</a></span></li><li><span><a href="#Попробуем-прикрутить-целевые-признаки-к-тестовой-выборке" data-toc-modified-id="Попробуем-прикрутить-целевые-признаки-к-тестовой-выборке-1.0.4"><span class="toc-item-num">1.0.4&nbsp;&nbsp;</span>Попробуем прикрутить целевые признаки к тестовой выборке</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Выводы:" data-toc-modified-id="Выводы:-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>Выводы:</a></span></li></ul></li><li><span><a href="#Сравним-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной." data-toc-modified-id="Сравним-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-Если-распределения-сильно-отличаются-друг-от-друга,-оценка-модели-будет-неправильной.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Сравним распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.</a></span><ul class="toc-item"><li><span><a href="#Исследуем-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="Исследуем-суммарную-концентрацию-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span></li></ul></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Напишем-функцию-для-вычисления-итоговой-sMAPE." data-toc-modified-id="Напишем-функцию-для-вычисления-итоговой-sMAPE.-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Напишем функцию для вычисления итоговой sMAPE.</a></span></li></ul></li><li><span><a href="#Обучение-моделей-и-оценка-их-качества-кросс-валидацией" data-toc-modified-id="Обучение-моделей-и-оценка-их-качества-кросс-валидацией-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Обучение моделей и оценка их качества кросс-валидацией</a></span><ul class="toc-item"><li><span><a href="#DecisionTreeRegressor" data-toc-modified-id="DecisionTreeRegressor-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>DecisionTreeRegressor</a></span></li><li><span><a href="#RandomForestRegressor" data-toc-modified-id="RandomForestRegressor-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>RandomForestRegressor</a></span></li><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#DummyRegressor" data-toc-modified-id="DummyRegressor-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>DummyRegressor</a></span></li><li><span><a href="#Проведем-тестирование--лучшей-модели-на-тестовых-данных-c-подобранными-гиперпараметрами:" data-toc-modified-id="Проведем-тестирование--лучшей-модели-на-тестовых-данных-c-подобранными-гиперпараметрами:-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Проведем тестирование  лучшей модели на тестовых данных c подобранными гиперпараметрами:</a></span></li></ul></li><li><span><a href="#Общий-вывод:" data-toc-modified-id="Общий-вывод:-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Общий вывод:</a></span></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ### Импорт  и установка библиотек

# %%
import pandas as pd
import numpy as np

import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, make_scorer
from collections import namedtuple

#models
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor

state = np.random.RandomState(12345)
pd.set_option('display.max_columns', None)
TARGETS = ['rougher.output.recovery', 'final.output.recovery']

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> Хорошее оформление импортов! \
# Импорты собраны в одной ячейке, разделены на функциональные группы пустой строкой.</font>

# %% [markdown]
# ## Подготовка данных

# %%
train_df = pd.read_csv('/datasets/gold_recovery_train_new.csv')
test_df = pd.read_csv('/datasets/gold_recovery_test_new.csv')
full_df = pd.read_csv('/datasets/gold_recovery_full_new.csv')

# %%
#напишем функцию для обзора данных
def data_info(dataset):
    cols = dataset.columns
    colours = ['#000099', '#ffff00'] 
    sns.heatmap(dataset[cols].isnull(), cmap=sns.color_palette(colours))
    print('Head:')
    display(dataset.head())
    print('')
    print('Corr:')
    display(dataset.corr())
    print('')
    print('Describe:')
    print('')
    display(dataset.describe())  
    print('Info:')
    print('')
    display(dataset.info())   
    print('Duplicated:')
    #print('')
    display(dataset[dataset.duplicated ()])

# %%
data_info(train_df)
# Out:
# Head:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
data_info(test_df)
# Out:
# Head:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
data_info(full_df)
# Out:
# Head:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Данные загружены корректно, первичный осмотр проведен.</font>

# %% [markdown]
# Вывод:
# - Очень большое количество столбцов, это усложняет анализ, по всех трех датасетах есть пропуски, в незначительном кол-ве, заполним их с помощью метода `ffill`.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'> Заполнение пропусков одним значением не совсем корректно. В задаче есть условие,что соседние данные похожи. Можно использовать метод `ffill`</font>

# %% [markdown]
# <font color='purple'><b>Комментарий студента</b></font> Поправил вывод

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'>👍</font>

# %% [markdown]
# #### Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.
#
# Напишем функцию для расчета Recovery по формуле
#
# $$Recovery =\frac{C\cdot(F - T)}{F\cdot(C - T)}\cdot 100\%$$
#
# - C — доля золота в концентрате после флотации/очистки ( **rougher.output.concentrate_au** )
# - F — доля золота в сырье/концентрате до флотации/очистки ( **rougher.input.feed_au** )
# - T — доля золота в отвальных хвостах после флотации/очистки ( **rougher.output.tail_au** )

# %%
c = train_df['rougher.output.concentrate_au']
f = train_df['rougher.input.feed_au']
t = train_df['rougher.output.tail_au']
train_df['recovery_new'] = (c * (f - t)) / (f * (c - t)) * 100
#* (rougher.input.feed_au - rougher.output.tail_au)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Расчёт верный!</font>

# %% [markdown]
# - Найдите MAE между вашими расчётами и значением признака. Опишите выводы.

# %%
mae = mean_absolute_error(train_df['recovery_new'], train_df['rougher.output.recovery'])
print(mae, round(mae, 5))
# Out:
# 9.73512347450521e-15 0.0

# %% [markdown]
# **Вывод:** *MAE* минимально,  при округлении нулевое, значит эффективность обогащения рассчитана правильно.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>👍</font>

# %% [markdown]
# #### Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?

# %%
def fields_diff(first_df, second_df):
    return set(first_df.columns.to_list()) - set(second_df.columns.to_list())

# %%
mising_fields = fields_diff(train_df, test_df)
print(train_df[mising_fields].dtypes)
# Out:
# final.output.concentrate_au                           float64
# primary_cleaner.output.tail_pb                        float64
# primary_cleaner.output.concentrate_au                 float64
# secondary_cleaner.output.tail_ag                      float64
# final.output.tail_ag                                  float64
# final.output.tail_pb                                  float64
# rougher.calculation.floatbank11_sulfate_to_au_feed    float64
# final.output.tail_au                                  float64
# final.output.concentrate_ag                           float64
# recovery_new                                          float64
# rougher.output.tail_pb                                float64
# rougher.output.tail_au                                float64
# rougher.output.concentrate_pb                         float64
# primary_cleaner.output.concentrate_pb                 float64
# secondary_cleaner.output.tail_au                      float64
# ...

# %% [markdown]
#  **Вывод:**
#  - Все отсутствующие значения в тестовой выборке типа **float64**
#  - Числовые
#  - **rougher.output.recovery** целевой числовой.
#  - На первый взгляд эта выборка  вообще не релевантна ввиду отсутствия целевого признака, по которому мы должны оценить качество модели.
#  - Попробуем прикрутить целевой признак с помощью джоина по датам

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'> В выборке собраны переменные доступные до начала технологического процесса, по этим признакам модель будет прогнозировать целевые переменные, значит данных для теста достаточно. Тестовые таргеты нужны для оценки качества работы модели.</font>

# %% [markdown]
# <font color='purple'><b>Комментарий студента</b></font> Поправил вывод

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'>👍</font>

# %% [markdown]
# #### Проведите предобработку данных.
# - Заполним пропуски с помощью `ffill`

# %%
train_df = train_df.ffill(axis = 0)
test_df = test_df.ffill(axis = 0)
full_df = full_df.ffill(axis = 0)

# %% [markdown]
# <font color='purple'><b>Комментарий студента</b></font> Поправил заполнение на `ffill`

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'> Пропуски заполнены согласно условию задачи!</font>

# %% [markdown]
# #### Попробуем прикрутить целевые признаки к тестовой выборке

# %%
#Конечно же у нас получилось приджойнить (примерджить)  целевые признаки к датафрейму
test_df = pd.merge(test_df,full_df[['date'] + TARGETS], on=['date','date'])

train_df = train_df.drop(['date'], axis = 1)
test_df = test_df.drop(['date'], axis = 1)

test_df.head()
# Out:
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                     210.800909                         14.993118
# 1                     215.392455                         14.987471
# 2                     215.259946                         12.884934
# 3                     215.336236                         12.006805
# 4                     199.099327                         10.682530
#
#    primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0                         8.080000                        1.005021
# 1                         8.080000                        0.990469
# 2                         7.786667                        0.996043
# 3                         7.640000                        0.863514
# 4                         7.530000                        0.805575
#
#    primary_cleaner.state.floatbank8_a_air  \
# 0                             1398.981301
# 1                             1398.777912
# ...

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'> Верно, при пересечении таблиц лучше привязаться ко времени.</font>

# %% [markdown]
# <font color='purple'><b>Комментарий студента</b></font> Перенес удаление даты выше.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# - Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки.

# %%
#Выделим из всего хаоса столбцов, нужные нам:
#Пройдемся по таблице списком металов:
metal_list= ['au', 'ag', 'pb']

cols = []
for c in full_df.columns:
        for m in metal_list:
            if m in c:
                cols.append(c)
        
cols = sorted(cols)

display(cols)
# Out:
# ['final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.input.feed_ag',
#  'rougher.input.feed_au',
#  'rougher.input.feed_pb',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_au',
#  'rougher.output.tail_pb',
#  'secondary_cleaner.output.tail_ag',
# ...

# %%
c_metrics = [
    'rougher.input.feed',
    'rougher.output.concentrate',
    'primary_cleaner.output.concentrate',
    'final.output.concentrate'
]



for metal in metal_list:
    metrics = ['{}_{}'.format(x, metal) for x in c_metrics]

    full_df[metrics].plot(
        title = 'Концентрация {} на различных этапах очистки'.format(metal.upper()),
        kind='hist', 
        bins=200, 
        grid=True, 
        legend=True,
        figsize=(20, 5),
        alpha=0.7,
    )
    plt.show()

# %% [markdown]
# #### Выводы:
# - Концентрация золота на этапе сырья и на этапе продукта примерно одинакова, падает на этапе первичной очистки
# - Концентрация серебра имеет отрицательную динамику, т.е. самая высокая на этапе сырья и потихоньку уменьшается,  принимая минимальные значения на финальном этапе
# - Динамика концентрации свинца похожа на динамику серебра, высокая на первом этапе, снижается на последнем.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'> На каком этапе концентрация серебра самая высокая?</font>

# %% [markdown]
# <font color='purple'><b>Комментарий студента</b></font> Поправил вывод

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'>Всётаки самая высокая на флотации </font>

# %% [markdown]
#  ### Сравним распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.

# %%
for metric in ('rougher.input.feed_size', 'primary_cleaner.input.feed_size'):
    for label, df in (('train', train_df), ('test', test_df)): 
        df[metric].plot(
                title = 'Распределение размеров гранул сырья на обучающей и тестовой выборках для {}'.format(metric),
                kind='hist', 
                density=True,
                bins=100, 
                grid=True, 
                legend=True,
                figsize=(10, 5),
                alpha=0.5,
                label=label,
            ).set(xlabel='concentrate')
  
    plt.show()

# %% [markdown]
# **Вывод:**
# - По графику видно что распределение размеров гранул совпадает,  оценки модели будут правильными.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> Вывод верный!</font> \
# <font color='darkorange'> В данном случае нужно использовать параметр "density=True" в методе ".hist()". Так бы нам удалось перейти от количества к доле.</font>
#
# <font color='purple'><b>Комментарий студента</b></font> Спасибо! Так правда лучше!

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'> Супер! Выборки разного размера, нужна нормализация по плотности 👍</font>

# %% [markdown]
# #### Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %%
for metric in c_metrics:
    train_df[metric] = 0
    for metal in metal_list + ['sol']:
        train_df[metric] += train_df['{}_{}'.format(metric, metal)]
    
train_df[c_metrics].head(5)
# Out:
#    rougher.input.feed  rougher.output.concentrate  \
# 0           51.680034                   66.424950
# 1           50.659114                   67.012710
# 2           50.609929                   66.103793
# 3           51.061546                   65.752751
# 4           47.859163                   65.908382
#
#    primary_cleaner.output.concentrate  final.output.concentrate
# 0                           72.640924                 63.644396
# 1                           72.543485                 63.957723
# 2                           72.095042                 64.311180
# 3                           59.957723                 63.573449
# 4                           71.321010                 64.004667

# %% [markdown]
# Определим класс, который посчитает границы нормальных значений (т.е Q1 - 1.5 * IQR и Q3 + 1.5 * IQR) и затем сможет нарисовать графики по ним.

# %%
NormalRange = namedtuple('NormalRange', ('min', 'max'))

class NormalRangeAnalyzer(object):
    MIN_VIEW_BOXPLOT_MUL = 0.8
    MAX_VIEW_BOXPLOT_MUL = 1.2
    
    def __init__(self, df, column_name):
        self._series = df[column_name]
        self._column_name = column_name
        self._normal_range = self._compute_normal_range()
    
    def _compute_normal_range(self):
        min_, q1, q3, max_ = self._series.quantile([0, 0.25, 0.75, 1])
        iqr = q3 - q1
        return NormalRange(max(min_, q1 - 1.5 * iqr), min(max_, q3 + 1.5 * iqr))
    
    @property
    def column_name(self):
        return self._column_name
    
    @property
    def normal_range(self):
        return self._normal_range
    
    def describe(self):       
        print('Границы нормальных значений для столбца {}: ({:.2f}, {:.2f})'.format(
            self._column_name, 
            self._normal_range.min,
            self._normal_range.max,
        ))
        display(self._series.describe())
        
    def plot(self, bins=100):
        range_min = self._normal_range.min * self.MIN_VIEW_BOXPLOT_MUL
        range_max = self._normal_range.max * self.MAX_VIEW_BOXPLOT_MUL
        
        fig, axes = plt.subplots(nrows=1, ncols=2)
        
        self._series.plot(
            kind='box',
            ax=axes[0],
            grid=True,
            ylim=(range_min, range_max),
            figsize=(20,5),
        )
        
        self._series.plot(
            kind='hist', 
            ax=axes[1],
            bins=bins, 
            title=self._column_name,
            grid=True,
            figsize=(20,5),
        )
        plt.show()

# %% [markdown]
# - Выведем гистограммы и диаграммы размаха для всех признаков

# %%
range_analyzers = []

for metric in c_metrics:
    range_analyzer = NormalRangeAnalyzer(train_df, metric)
    range_analyzer.describe() 
    range_analyzer.plot() 
    range_analyzers.append(range_analyzer)
# Out:
# Границы нормальных значений для столбца rougher.input.feed: (40.29, 73.05)
# count    14149.000000
# mean        56.242170
# std          7.029808
# min          0.040000
# 25%         52.573579
# 50%         56.627635
# 75%         60.763234
# max         74.458253
# Name: rougher.input.feed, dtype: float64
# Границы нормальных значений для столбца rougher.output.concentrate: (52.14, 86.20)
# count    14149.000000
# mean        67.173145
# std         12.713129
# min          0.000000
# 25%         64.914390
# 50%         69.175663
# 75%         73.429261
# max         88.140119
# Name: rougher.output.concentrate, dtype: float64
# Границы нормальных значений для столбца primary_cleaner.output.concentrate: (47.08, 76.32)
# count    14149.000000
# mean        60.172546
# std         10.448165
# min          0.000000
# 25%         58.046816
# 50%         61.786946
# 75%         65.355951
# max         76.918076
# Name: primary_cleaner.output.concentrate, dtype: float64
# ...

# %% [markdown]
# Избавимся от аномальных данных в обучающей выборке

# %%
old_shape = train_df.shape

for range_analyzer in range_analyzers:    
    train_df = train_df[
        (train_df[range_analyzer.column_name] >= range_analyzer.normal_range.min) & 
        (train_df[range_analyzer.column_name] <= range_analyzer.normal_range.max)
    ]
    
new_shape = train_df.shape

print('Удалено строк:', old_shape[0] - new_shape[0])
# Out:
# Удалено строк: 2218

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ⚠️\
# <font color='darkorange'> Очень жёсткая очистка, учитывая заполнение пропусков нулями.</font>
#
# <font color='purple'><b>Комментарий студента</b></font> Пропуск нулями заменил на `ffill`

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'> Выбросы удалены.</font>

# %% [markdown]
# ## Модель

# %% [markdown]
# - Тестовая выборка не релевантна,  поэтому с помощью **train_test_split** выделим из **full_df** часть для тестов

# %%
missing_test_fields = fields_diff(train_df, test_df)
print(missing_test_fields)
train_df = train_df.drop(missing_test_fields, axis='columns')
print(fields_diff(train_df, test_df))
print(fields_diff(test_df, train_df))
# Out:
# {'final.output.concentrate_au', 'primary_cleaner.output.tail_pb', 'primary_cleaner.output.concentrate_au', 'rougher.output.concentrate', 'secondary_cleaner.output.tail_ag', 'final.output.tail_ag', 'final.output.tail_pb', 'final.output.concentrate', 'rougher.calculation.floatbank11_sulfate_to_au_feed', 'final.output.tail_au', 'final.output.concentrate_ag', 'recovery_new', 'rougher.output.tail_pb', 'rougher.output.tail_au', 'rougher.output.concentrate_pb', 'primary_cleaner.output.concentrate_pb', 'secondary_cleaner.output.tail_au', 'primary_cleaner.output.concentrate_sol', 'primary_cleaner.output.tail_sol', 'rougher.output.tail_sol', 'final.output.tail_sol', 'final.output.concentrate_sol', 'rougher.output.concentrate_au', 'rougher.calculation.floatbank10_sulfate_to_au_feed', 'primary_cleaner.output.concentrate_ag', 'rougher.input.feed', 'rougher.output.tail_ag', 'primary_cleaner.output.tail_au', 'rougher.calculation.sulfate_to_au_concentrate', 'secondary_cleaner.output.tail_pb', 'rough
# ...

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'><s> Наоборот тестовая выборка наиболее релевантная, поскольку в задаче использовать именно ёё.\
#     Таргеты для теста можно извлечь из Полной таблицы по общему признаку 'date'.</s></font>
#
#
# <font color='purple'><b>Комментарий студента</b></font>  Окей, тогда предлагаю такой вариант: оставили только те данные что есть в тестовой выборке, т.к. огромное количество  признаков  может  тоже негативно отразиться на обучаемости моделей.

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'> Отлично! Это то что нужно!</font>

# %% [markdown]
# #### Напишем функцию для вычисления итоговой sMAPE.

# %%
def calculate_smape(target_actual, target_predictions):
    numerator = np.abs(target_actual - target_predictions)
    denominator = (np.abs(target_actual) + np.abs(target_predictions)) / 2 
    
    return 1 / len(target_actual) * np.sum(numerator / denominator) * 100 
    
    
def calculate_final_smape(target_actual, target_predictions):
    target_actual_rougher = target_actual['rougher.output.recovery']
    target_actual_final = target_actual['final.output.recovery']
    
    target_predictions_rougher = target_predictions[:, 0]
    target_predictions_final = target_predictions[:, 1]
    
    return 0.25 * calculate_smape(target_actual_rougher, target_predictions_rougher) \
        + 0.75 * calculate_smape(target_actual_final, target_predictions_final)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'> `smape` расчитана верно.</font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'><s> В calculate_final_smape в расчёте взвешенной суммы оба раза применяются метрики rougher.</s></font>
#
# <font color='purple'><b>Комментарий студента</b></font> Спасибо, поправил

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'> `calculate_final_smape` расчитана верно.</font>

# %% [markdown]
# Создадим scorer для того, чтобы использовать его при кросс-валидации

# %%
smape_scorer = make_scorer(calculate_final_smape, greater_is_better=False)

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️ <br>
# <font color='green'>Верно, что не забываешь указать greater_is_better=False, Это пригодится для SearchCV. SMAPE — ошибка, её минимизируем.</font>

# %% [markdown]
# ### Обучение моделей и оценка их качества кросс-валидацией

# %% [markdown]
# - Выделим фичи и целевые показатели rougher.output.recovery и final.output.recovery

# %%
features_train = train_df.drop(TARGETS, axis='columns')
target_train = train_df[TARGETS]
features_test = test_df.drop(TARGETS, axis='columns')
target_test = test_df[TARGETS]

# %% [markdown]
# - Теперь обучим модели и посмотрим, какая даст лучшее значение sMAPE

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'><s> В момент предполгаемого применения модели в продакте, доступны только признаки собранные в тестовом датасете. Нужно построить модель работающую только с этими признаками.</s>  </font>
#
# <font color='purple'><b>Комментарий студента</b></font> Отлично! Я как раз  удалил лишние чуть выше

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'>Супер!</font>

# %%
models_review = []

# %% [markdown]
# #### DecisionTreeRegressor

# %%
param_grid = {'max_depth': range(2, 11)}

model = DecisionTreeRegressor(random_state=state)
search = GridSearchCV(model, param_grid, cv=5, scoring=smape_scorer)
search.fit(features_train, target_train)
print('Лучшее значение sMAPE для дерева решений: {} при значениях гиперпараметров: {}'.format(-search.best_score_, search.best_params_))

models_review.append(['DecisionTreeRegressor',  -search.best_score_])
# Out:
# Лучшее значение sMAPE для дерева решений: 8.401223146488448 при значениях гиперпараметров: {'max_depth': 2}

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера : </b></font> ✔️\
# <font color='green'>Подбор гиперпараметров проведён верно. Использована целевая метрика, направление отбора верное ).</font>

# %% [markdown]
# #### RandomForestRegressor

# %%
param_grid = {'n_estimators': range(10, 31, 10)}

model = RandomForestRegressor(max_depth=2, random_state=state)
search = GridSearchCV(model, param_grid, cv=5, scoring=smape_scorer)
search.fit(features_train, target_train)
print('Лучшее значение sMAPE для случайного леса: {} при значениях гиперпараметров: {}'.format(-search.best_score_, search.best_params_))

models_review.append(['RandomForestRegressor',  -search.best_score_])
# Out:
# Лучшее значение sMAPE для случайного леса: 8.219452839451655 при значениях гиперпараметров: {'n_estimators': 20}

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>👍</font>

# %% [markdown]
# #### LinearRegression

# %%
model = LinearRegression()
model.fit(features_train, target_train)
smape = cross_val_score(model, features_train, target_train, cv=5, scoring=smape_scorer).mean()
print('Лучшее значение sMAPE для линейной регрессии:', -smape)

models_review.append(['LinearRegression',  -smape])
# Out:
# Лучшее значение sMAPE для линейной регрессии: 9.082326085167017

# %% [markdown]
# #### DummyRegressor

# %%
model = DummyRegressor()
model.fit(features_train, target_train)
smape = cross_val_score(model, features_train, target_train, cv=5, scoring=smape_scorer).mean()
print('Лучшее значение sMAPE для куска дерева:', -smape)

models_review.append(['DummyRegressor',  -smape])
# Out:
# Лучшее значение sMAPE для куска дерева: 8.855765634895686

# %%
display(models_review)
# Out:
# [['DecisionTreeRegressor', 8.401223146488448],
#  ['RandomForestRegressor', 8.219452839451655],
#  ['LinearRegression', 9.082326085167017],
#  ['DummyRegressor', 8.855765634895686]]

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>👍</font>

# %% [markdown]
# #### Проведем тестирование  лучшей модели на тестовых данных c подобранными гиперпараметрами:

# %%
model = RandomForestRegressor(random_state=state, n_estimators =  20)
model.fit(features_train, target_train)
predictions = model.predict(features_test)
print('Лучшее значение sMAPE для случайного леса: {}'.format(min(calculate_smape(target_test, predictions))))
# Out:
# Лучшее значение sMAPE для случайного леса: 8.245648449740916

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ✔️\
# <font color='green'>Тестирование проведено верно.</font>

# %% [markdown]
# ### Общий вывод:
#
# - Подготовили данные, при подготовке данных был использован переходящий и совершенствующийся с каждым проектом скрипт анализа: **data_info**, провели предобработку данных, были пропущенные значения которые в итоге заполнили с помощью `ffill` а также прикрутили целевые признаки к тестовой выборке заджойнив по датам. А даты потом удалили.
#
# - Провели исследовательский анализ данных, проверили концентрации металлов на этапе сырья, промежуточном этапе и финальном. Самая большая концентрация золота вначала и в конце, на этапе очистки уходит в хвосты, поэтому уменьшается.
# Кон
# 3. Построить и обучить модель.
#
# - Случайный лес показал лучшее значение **sMAPE: 8.21** при параметре **n_estimators 20**.
# - На тестовой выборке **sMAPE: 8.24**
# - Самые неправильные значения показывает линейная регрессия, если **DummyRegressor** специально придуман чтобы показывать погоду то линейная регрессия придумана чтобы прогнозировать погоду по прогнозам **DummyRegressor** )

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера 2: </b></font> ✔️\
# <font color='green'> Очень приятно видеть вывод в конце проекта!\
# Приведены ответы на главные вопросы проекта.</font>

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера 2</b></font>\
# <font color='green'> Станислав, проект принят! \
# Все этапы пройдены. Все рекомендации учтены.\
# Надеюсь, тебе понравился процесс выполнения и результат.</font> \
# <font color='blue'><b>Спасибо, удачи в освоении профессии!</b></font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'><s> sMAPE - это метрика ошибки она чем меньше - тем лучше.</s></font>
#
# <font color='purple'><b>Комментарий студента</b></font> Принял

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'><s>Нужно провести тестирование Лучшей модели на тестовых данных. (из таблицы gold_recovery_test_new.csv)</s></font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'><s> Результат тестирования нужно сравнить с константной моделью, например с `DummyRegressor`, из одного значения метрики не ясно насколько адекватно предсказание моделей. )</s></font>

# %% [markdown]
# <font color='blue'><b>Комментарий ревьюера: </b></font> ❌\
# <font color='red'><s> Очень не хватает общего вывода. В выводах можно приводить полученные ранее значения. Также можно расписать все, что было сделано в ходе проведения работы.</s></font>

# %% [markdown]
# <font color='blue'><b>Итоговый комментарий ревьюера</b></font>
#
# <font color='blue'>К сожалению, проект не готов. Присылай законченную версию. По всем непонятным моментам можно обращаться за помощью наставникам и преподавателям, а также комьюнити студентов. Буду ждать :)
#
# </font>

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке выполнения
# - [x]  Выполнен шаг 1: данные подготовлены
#     - [x]  Проверена формула вычисления эффективности обогащения
#     - [x]  Проанализированы признаки, недоступные в тестовой выборке
#     - [x]  Проведена предобработка данных
# - [x]  Выполнен шаг 2: данные проанализированы
#     - [x]  Исследовано изменение концентрации элементов на каждом этапе
#     - [x]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [x]  Исследованы суммарные концентрации
# - [x]  Выполнен шаг 3: построена модель прогнозирования
#     - [x]  Написана функция для вычисления итогового *sMAPE*
#     - [x]  Обучено и проверено несколько моделей
#     - [x]  Выбрана лучшая модель, её качество проверено на тестовой выборке
