# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
#
# Привет, Станислав! Давай знакомиться! Меня зовут Дмитрий Махортов, и я буду проверять твой проект. Сразу предлагаю общение на «ты» 🙂, но если тебе это не комфортно, то дай знать, и мы перейдем на «вы».
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе погрузиться в увлекательный мир работы с данными и вырасти в крепкого профи. Это отдаленная цель. А ближайшая - сделать твою работу еще лучше )).
#
#
# Все ключевые этапы в работе выполнены, и я вижу что с проектом ты справшяешься. Есть моменты, которые нужно доработать, но я уверен, у тебя все получится.
#
# Расскажу как обычно проходит проверка:
# Бывают моменты, которые требуют пристального внимания. Комментарии по ним выделены <span style='background-color:#F7B3A4'> красным цветом </span> и обозначены значком 🛑. После их доработки проект будет принят.  🙂
#
# <span style='background-color:#B7EBA7'> Зеленым цветом </span> и значком ✅ отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. Или советы «со звездочкой», которые помогут тебе в будущем.
#
# <span style='background-color:#F9EDA6'>Жёлтым цветом </span> и значком ⚠️ выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Можешь использовать этот комментарий. Просто удали этот текст и вместо него напиши свой 🙂
#
# </div>

# %% [markdown]
# # Определение возраста покупателей

# %% [markdown]
# ## Исследовательский анализ данных

# %%
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, все нужные библиотеки импортированы в начале ноутбука.Это хорошая практика.</div>

# %%
labels = pd.read_csv('/datasets/faces/labels.csv')
datagen = ImageDataGenerator(rescale=1./255)
datagen_flow = datagen.flow_from_dataframe(
        dataframe=labels,
        directory='/datasets/faces/final_files/',
        x_col='file_name',
        y_col='real_age',
        target_size=(224, 224),
        batch_size=32,
        class_mode='raw',
        seed=12345)
# Out:
# Found 7591 validated image filenames.

# %%
snsplot = sns.kdeplot(labels['real_age'], shade=True)
fig = snsplot.get_figure()

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Создание датагенератора и вывод графика распределения возраста - это две важные, но очень разные задачи. Целесообразно разделить их по разным ячейкам, а не склеивать в одну. Это затруднит чтение и восприятие проекта.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Отделил датаген от графика
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>v2</b> 👍 </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Теперь ты знаешь количество фотографий в датасете. Учитывая эту информацию, а также то, что ты знаешь что мы решаем задачу регрессии, попробуй порассуждать, достаточно ли имеющихся данных? Какие шаги мы можем предпринять в связи с этим?
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Добавил рассуждения в вывод по шагу
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> ответ ревьюера v2</b>
#
# Посмотрел.  Здесь оставлю свою версию ответа.
#
# На самом деле однозначно понять, достаточно ли фотографий сложно. Очень много зависит от доменной области (медицина или спутниковые снимки), требований заказчика к точности, качества датасета, шумности разметки и т.д.
#
# Но прибрести опыт и интуицию, чтобы хотябы приблизительно оценить можно и нужно. Именно поэтому я предложил тебе задуматься над этим вопросом и порассуждать.
#
#
# Давай попробую привести свою оценку. Есть средняя "в вакууме" оценка - 1000 изображений на класс для задачи классификации. Мы решаем задачу регрессии, нужно получить mae меньше 8. Можно представить близкую задачу классификации на 15 классов, которая дает похожую точность. В этом случае нам нужно 15000 изображений, т.е.в два раза больше чем у нас есть. Но хорошая новость - в два раза это не в десять, к тому же мы можем использовать отражения, поэтому по предварительной оценке данных должно хвататить.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента2</b></font>
#
# Понял тебя, спасибо за развернутый ответ!
# Пойду добавлю рассуждений об аугментации ниже )
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Верно использован ImageDataGenerator как инструмент для доступа к потоку фотографий. Но обрати внимание на название переменных train_datagen  и train_gen_flow. На мой взгляд они не соответсвуют тому, что в них, ведь ты еще не производишь разделение потоков фотографий на обучающий и валидационный наборы.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Исправил название переменных
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>v2</b> 👍 </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Исследовано распрпделение возраста с помощью графика ядерной оценки плоотности. Это позволяет понять как распределен возраст. Но прошу тебя дополнительно вывести гистограмму (взять количество корзин равное 100), это помогает увидеть некоторые особенности, присущие именно нашему датасету.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Вывел гистограмму с кол-вом корзин 100 чуть ниже, на что нужно обратить внимание?
#
# </div>

# %%
snsplot = sns.kdeplot(labels['real_age'], shade=True)
fig = snsplot.get_figure()

# %%
sns.histplot(data=labels['real_age'], bins = 100);

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>v2</b> Посмотри на всплески количества значений (пики) в круглые даты - 25-30-40-50-60 и далее каждые 10 лет. Это указывает на огрехи в разметке датасета, например ручую разметку + округления. </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# <b>v2</b>
#
# Прошу избавиться от вывода текстового представления python-объектов, которые возвращают используемые тобой функции например
#
#     <AxesSubplot:xlabel='real_age', ylabel='Count'>
#
# Это можно сделать достаточно просто, если добавить  точку с запятой после последней команды в ячейке.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента 2</b></font>
#
# Классная фишка, спасибо! (убрал)
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>v3</b> выполнено </div>

# %%
#обзор датафрейма
display(labels.shape)
# Out:
# (7591, 2)

# %%
# выводим изображения
features, target = next(datagen_flow)
fig = plt.figure(figsize=(20,20))
for i in range(15):
    ax = fig.add_subplot(4, 4, i+1)
    
    plt.imshow(features[i])
    ax.set(title = target[i])
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Не стоит в одной ячейке исследовать размерность датафрейма и выводить изображения. Это слишком разноплановые задачи.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# Отделил
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>v2</b> 👍 </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Очень хорошо, что выведены фотографии. Это хорошая практика, помогает увидеть изображения, с которыми будет работать наша модель, заметить какие-то детали и особенности, улучшить понимание задачи и получить определенную интуицию. А также заранее оценить подходящие для наших данных методы аугментации. </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Кстати, можно дополнительно вывести возраст человека на фото, он содержится в переменной target. </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
# Вывел возраст
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>v2</b> 👍 </div>

# %% [markdown]
# ### Вывод по шагу:
# - 7591 фотографий,  фотографий не то чтобы много, для улучшения точности модели мы используем аугментацию отражения изображений по горизонтали.
# - Возраст в основном от 18 до 45
# - Фотографии сделаны с различных ракурсов, разные по качеству, некоторые являются фотографиями фотокарточек, некоторые просто фотографиями. Также имеется различный поворот, эти параметры помогут в работе модели, т.к. можно сказать, это ествественная аугментация.
# - Модель лучше всего обучится на распознавании возрастной группы от 18 до 45, остальное разпознавание будет хуже, но фактически это нормально т.к. целевая аудитория магащзина у нас как раз примерно такая.

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студент 2</b></font>
# Кратко дописал, зачем мы будем применять аугментацию. В шаге ниже  уберу лишнюю аугментацию.
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Пожалуйста сделай более подробные наблюдения, касающиеся избражений, входящих в датасет кроме "фотографии абсолютно разные".
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
# Добавил более подробные рассуждения
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>v2</b> 👍 </div>

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# Перенесите сюда код обучения модели и её результат вывода на экран.
#
#
# (Код в этом разделе запускается в отдельном GPU-тренажёре, поэтому оформлен не как ячейка с кодом, а как код в текстовой ячейке)

# %% [markdown]
# ```python
#
# # < скопируйте код сюда >
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Conv2D, AvgPool2D, Flatten
# import numpy as np
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.applications.resnet import ResNet50
# from keras.callbacks import Callback
# import pandas as pd
#
# EARLY_STOP_VALUE = 6.0
#
# class EarlyStoppingValAcc(Callback):
#     def __init__(self, monitor='val_mean_absolute_error', value=EARLY_STOP_VALUE, verbose=1):
#         super(Callback, self).__init__()
#         self.monitor = monitor
#         self.value = value
#         self.verbose = verbose
#
#     def on_epoch_end(self, epoch, logs={}):
#         current = logs.get(self.monitor)
#         if current is None:
#             warnings.warn("Early stopping requires %s available!" % self.monitor, RuntimeWarning)
#
#         if current < self.value:
#             if self.verbose > 0:
#                 print("Epoch %05d: early stopping THR" % epoch)
#             self.model.stop_training = True
#
# def load_train(path):
#
#     csv_file = pd.read_csv(path + '/labels.csv')
#     final_dir = path + '/final_files/'
#
#     train_datagen = ImageDataGenerator(validation_split=0.25, rescale=1/255.,
#                                    horizontal_flip=1,
#                                    #vertical_flip=True,
#                                    #rotation_range=90,
#                                    #width_shift_range=0.2,
#                                    #height_shift_range=0.2
#                                    )
#
#
#     train_data = train_datagen.flow_from_dataframe(
#                                                             dataframe=csv_file,
#                                                             directory= final_dir,
#                                                             x_col='file_name',
#                                                             y_col='real_age',
#                                                             target_size=(224, 224),
#                                                             batch_size=32,
#                                                             class_mode='raw',
#                                                             seed=12345,
#                                                             subset='training'
#                                                             )
#
#     return train_data
#
#
# def load_test(path):
#
#     csv_file = pd.read_csv(path + '/labels.csv')
#     final_dir = path + '/final_files/'
#
#     test_datagen = ImageDataGenerator(validation_split=0.25, rescale=1/255.
#                                    #horizontal_flip=1,
#                                    #vertical_flip=True,
#                                    #rotation_range=90,
#                                    #width_shift_range=0.2,
#                                    #height_shift_range=0.2
#                                    )
#
#
#     test_data= test_datagen.flow_from_dataframe(
#                                                         dataframe= csv_file,
#                                                         directory= final_dir,
#                                                         x_col='file_name',
#                                                         y_col='real_age',
#                                                         target_size=(224, 224),
#                                                         batch_size=32,
#                                                         class_mode='raw',
#                                                         seed=12345,
#                                                         subset='validation')
#
#     return test_data
#
#
# def create_model(input_shape):
#     #print('input shape is ', input_shape)
#
#     backbone = ResNet50(input_shape=input_shape,
#                     #weights='imagenet',
#                     weights='/datasets/keras_models/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5',
#                     include_top=False)
#
#     # замораживаем ResNet50 без верхушки
#     #backbone.trainable = False
#
#     model = Sequential()
#     model.add(backbone)
#     model.add(GlobalAveragePooling2D())
#     model.add(Dense(1, activation='relu'))
#
#     optimizer = Adam(lr=0.0001)  #0,0001 #0.001
#     model.compile(optimizer=optimizer, loss='mean_squared_error', #mean_squared_error #mean_absolute_error
#                   metrics=['mean_absolute_error'])
#
#     return model
#
#
# def train_model(model, train_data, test_data, batch_size=None,
#                 epochs=20,
#                 steps_per_epoch=None, validation_steps=None):
#
#     es = [EarlyStoppingValAcc(monitor='val_mean_absolute_error', value=EARLY_STOP_VALUE, verbose=1)]
#
#     model.fit(train_data,
#               validation_data=test_data,
#               batch_size=batch_size,
#               epochs=epochs,
#               steps_per_epoch=steps_per_epoch,
#               validation_steps=validation_steps,
#               verbose=2
#               #, shuffle=True
#               , callbacks=es
#               )
#
#     return model
#
#
# ```

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# При анализе логов видна слишком хорошая точность для валидационного набора. Так не бывает. Возьми за правило - если метрики слишком хорошие, ищи утечку. Скорее всего где-то допущена ошибка и твоя модель получила доступ к валидационным данным.
#
# Проверь создание датагенераторов. Сейчас они у тебя идентичные, не производится разделение на валидацию и обучение (аргумент  subset)
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>v2</b> 👍 </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Написаны функции для создания датагенераторов, а также создания и обучения модели.
#
# </div>
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Советую использовать аугментацию для обучающего набора, хотя бы отражение по горизонтали.
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Молодец, что создал коллбэк, снимаю шляпу )) </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# В качестве лосс-функции ты использовал mae, это допустимо, но для задач регрессии более подходящей лосс-функцией является mse, с ней модели учатся быстрее и стабильнее. А mae лучше оставить в качестве метрики, которую ты дополнительно мониторишь.
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# На мой взгляд великовал lr. Попробуй взять 0,0001 и метрика может заметно улучшиться.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студента</b></font>
#
# - Спасибо что обратил мое внимание на **subset**! Действительно утечка данных :) устранил
# - Аугментацию для обучающего набора подключил
# - Функцию потерь поменял на **mse**
# - Шаг оптимизатора поменял на 0,0001
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# <b>v2</b>
# На этот раз ты сделал слишком сильную аугментацию. Я бы рекомендовал не подключать сразу тяжелую артиллерию, а идти от простого к сложному. Вначале отраажения по горизонтали, потом повороты на углы 10-15 градусов и сдвиги в пределах 10%.
#
# А сейчас ты учишь модель на изображениях, которые она никогда не встретит ни в тесте ни в продакшене (перевернутые вверх ногами или лежащие на боку). И из-за этого страдает точность модели.
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студент 2</b></font>
# Оставил только флип по горизонтали,  точность  улучшилась, спасибо!
# </div>

# %% [markdown]
# ```
# # < скопируйте результат вывода на экран сюда >
# Train for 178 steps, validate for 60 steps
# Epoch 1/20
# 2023-03-13 05:00:17.103644: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2023-03-13 05:00:17.437450: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 178/178 - 48s - loss: 299.4977 - mean_absolute_error: 12.1823 - val_loss: 966.6939 - val_mean_absolute_error: 26.3389
# Epoch 2/20
# 178/178 - 39s - loss: 82.2503 - mean_absolute_error: 6.8158 - val_loss: 640.2109 - val_mean_absolute_error: 19.8598
# Epoch 3/20
# 178/178 - 40s - loss: 55.1611 - mean_absolute_error: 5.6275 - val_loss: 252.9899 - val_mean_absolute_error: 11.8012
# Epoch 4/20
# 178/178 - 39s - loss: 37.5087 - mean_absolute_error: 4.6930 - val_loss: 111.4114 - val_mean_absolute_error: 8.2615
# Epoch 5/20
# 178/178 - 39s - loss: 28.8679 - mean_absolute_error: 4.0708 - val_loss: 95.9789 - val_mean_absolute_error: 7.5217
# Epoch 6/20
# 178/178 - 40s - loss: 22.0534 - mean_absolute_error: 3.5879 - val_loss: 64.8598 - val_mean_absolute_error: 6.1144
# Epoch 7/20
# 178/178 - 39s - loss: 17.2087 - mean_absolute_error: 3.1507 - val_loss: 69.9859 - val_mean_absolute_error: 6.2652
# Epoch 8/20
# 178/178 - 40s - loss: 15.1589 - mean_absolute_error: 2.9888 - val_loss: 67.3956 - val_mean_absolute_error: 6.3898
# Epoch 9/20
# 178/178 - 40s - loss: 12.7001 - mean_absolute_error: 2.7036 - val_loss: 66.5949 - val_mean_absolute_error: 6.1196
# Epoch 10/20
# 178/178 - 40s - loss: 11.1384 - mean_absolute_error: 2.5287 - val_loss: 70.5928 - val_mean_absolute_error: 6.4961
# Epoch 11/20
# Epoch 00010: early stopping THR
# 178/178 - 39s - loss: 8.8940 - mean_absolute_error: 2.2405 - val_loss: 60.1015 - val_mean_absolute_error: 5.8285
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 60/60 - 10s - loss: 60.1015 - mean_absolute_error: 5.8285
# Test MAE: 5.8285
# ```

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Нужная метрика достигнута, но обучающей выборке, т.к. обучение и оценка выполнялись на одних и тех же данных.
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# <b>v2</b> теперь все ОК </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментарий студент 2</b></font>
# Логи также обновил
#
# </div>

# %% [markdown]
# ## Анализ обученной модели

# %% [markdown]
#  #### Вывод:
#  - Была использована  модель ResNet50 без заморозки верхушки т.к. данных для обучения достаточно.
#  - Выходной нейрон 1 шт
#  - Оптимизатор **Adam** с шагом (0.0001)
#  - Класс **EarlyStoppingValAcc** для остановки по достижению **val_mean_absolute_error** параметра  ниже **6**
#  - В итоге удалось добиться точности на тестовой выборке: **5.8285**.
#  - **ResNet50** отлично подходит для задач компьютерного зрения
#  - Возможность своевременно останавливать обучение в данном случае не пригодилось т.к. параметр выше  заданного
#  - Теоретически точность модели можно еще улучшить, увеличив поличество эпох и увеличив датасет.
#  - Набор данных представляет по большей части выборку людей в возрасте от 18 до 45 лет, следовательно если подобную модель пускать в прод, датасет нужно дополнить фотографиями людей от 0 до 18, от 45 до 100

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Очень подробно, все по делу. </div>

# %% [markdown]
# ## Чек-лист

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Исследовательский анализ данных выполнен
# - [x]  Результаты исследовательского анализа данных перенесены в финальную тетрадь
# - [x]  MAE модели не больше 8
# - [x]  Код обучения модели скопирован в финальную тетрадь
# - [x]  Результат вывода модели на экран перенесён в финальную тетрадь
# - [x]  По итогам обучения модели сделаны выводы

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий</b>
#
# Давай подведем итоги.
# Ты провел содержательный EDA, а также использовал предобученную модель и c помощью finetuning и transfer-learning обучил нейронку определять возраст покупателей. Требуемая точность получена.
#
#
# Пожалуста добавь наблюдения, касающиеся изображений, взодящих в датасет.
#
# И обязательно доработай функции по созданию датагенераторов, нужно разделить обучающий и валидационые датагенераторы.
#
#
#
# Жду твой проект на финальное ревью :)
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий v2</b>
#
# Вижу что ты провел большую работу, молодец.
#
# Остался один формальный момент - прошу убрать "артефакты" при выводе гистограммы.
#
# И очень советую "убавить" аугментацию.
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> дополнительные материалы </b>
# В курсе уже есть ссылки на отдельные статьи. Со своей стороны поделюсь неплохими бесплатными курсами по нейронкам, дающим целостную картинку.
#
#    - "Дип Лернинг на пальцах" (https://www.youtube.com/playlist?list=PL5FkQ0AF9O_o2Eb5Qn8pwCDg7TniyV1Wb).
#    - Отличный бесплатный курс от Школы глубокого обучения МФТИ (https://stepik.org/org/dlschool), старт курса каждые пол года. Два семестра, один по основам и компьютерному зрению, второй по обработке естественного языка.
#    - "Нейронные сети и компьютерное зрение" от Samsung Research Russia (https://stepik.org/course/50352/syllabus). Есть также продолжение по NLP.
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий v3</b>
#
# Проект принят. Поздравляю и желаю дальнейших успехов!
# </div>
